# %%
# feature_0  same correlation for all resp 1..4
# .005225, .0011439, .003427, .013900

# weight - same correlation for all resp 1..4
# 0.16091, .012955, .009229, .005817

# feature_0 with weight always .005699
# weight 0..167
# feature_0 -1, 1

import numpy as np

import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


import warnings
warnings.filterwarnings('ignore')

import os

# %%
# input dir
print('input data dir')
for dirname, _, filenames in os.walk('../input/jane-street-market-prediction'):
    for fname in filenames:
        print(os.path.join(dirname, fname))
        
# !ls -l ../input/jane-street-market-prediction
        
        
# working dir
print('working directory')
for dirname, _, filenames in os.walk('/kaggle/working'):
    for fname in filenames:
        print(os.path.join(dirname, fname))
        
# !ls -l ../working
# Out:
# input data dir
# ../input/jane-street-market-prediction/example_sample_submission.csv
# ../input/jane-street-market-prediction/features.csv
# ../input/jane-street-market-prediction/example_test.csv
# ../input/jane-street-market-prediction/train.csv
# ../input/jane-street-market-prediction/janestreet/competition.cpython-37m-x86_64-linux-gnu.so
# ../input/jane-street-market-prediction/janestreet/__init__.py
# total 6084396
# -rw-r--r-- 1 nobody nogroup     110655 Dec 17 23:51 example_sample_submission.csv
# -rw-r--r-- 1 nobody nogroup   37841516 Dec 17 23:51 example_test.csv
# -rw-r--r-- 1 nobody nogroup      23870 Dec 17 23:51 features.csv
# drwxr-xr-x 2 nobody nogroup          0 Dec 17 23:51 janestreet
# -rw-r--r-- 1 nobody nogroup 6192438027 Dec 17 23:51 train.csv
# working directory
# /kaggle/working/__notebook_source__.ipynb
# total 4
# ---------- 1 root root 263 Jan 18 15:21 __notebook_source__.ipynb

# %%
train = pd.read_csv('../input/jane-street-market-prediction/train.csv')

features = list(train.columns)
print(features)
# Out:
# ['date', 'weight', 'resp_1', 'resp_2', 'resp_3', 'resp_4', 'resp', 'feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9', 'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17', 'feature_18', 'feature_19', 'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24', 'feature_25', 'feature_26', 'feature_27', 'feature_28', 'feature_29', 'feature_30', 'feature_31', 'feature_32', 'feature_33', 'feature_34', 'feature_35', 'feature_36', 'feature_37', 'feature_38', 'feature_39', 'feature_40', 'feature_41', 'feature_42', 'feature_43', 'feature_44', 'feature_45', 'feature_46', 'feature_47', 'feature_48', 'feature_49', 'feature_50', 'feature_51', 'feature_52', 'feature_53', 'feature_54', 'feature_55', 'feature_56', 'feature_57', 'feature_58', 'feature_59', 'feature_60', 'feature_61', 'feature_62', 'feature_63', 'feature_64', 'feature_65', 'feature_66', 'fe
# ...

# %%
train_dates = train['date'].value_counts()
print(train_dates)
print(train_dates.min(), train_dates.max())
print(train_dates.index.min(), train_dates.index.max())
# Out:
# 44     18884
# 45     15174
# 459    14603
# 85     13842
# 38     13631
# 47     13351
# 12     12866
# 18     12082
# 161    12064
# 43     11872
# 80     11366
# 63     10805
# 168    10607
# 37     10399
# 4      10305
# 5       9965
# 59      9873
# 462     9718
# 24      9708
# 1       9401
# 452     9294
# 16      9069
# 346     8584
# 69      8578
# 475     8484
# 231     8271
# 495     8251
# 196     8107
# 30      7979
# 46      7978
# 380     7930
# 274     7839
# 488     7829
# 276     7812
# 492     7524
# 468     7512
# 27      7491
# 31      7373
# 283     7317
# 454     7300
# 3       7221
# 427     7205
# 23      7158
# 9       7116
# 354     7048
# 394     7020
# 185     6983
# 223     6959
# 26      6954
# 32      6915
# 489     6879
# 8       6877
# 324     6791
# 235     6738
# 41      6726
# 17      6718
# 382     6704
# 262     6689
# 356     6688
# 393     6678
# 491     6658
# 438     6610
# 379     6545
# 353     6504
# 22      6492
# 267     6487
# ...

# %%
test = pd.read_csv('../input/jane-street-market-prediction/example_test.csv')

test_features = list(test.columns)
print(test_features)
# Out:
# ['weight', 'feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9', 'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14', 'feature_15', 'feature_16', 'feature_17', 'feature_18', 'feature_19', 'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24', 'feature_25', 'feature_26', 'feature_27', 'feature_28', 'feature_29', 'feature_30', 'feature_31', 'feature_32', 'feature_33', 'feature_34', 'feature_35', 'feature_36', 'feature_37', 'feature_38', 'feature_39', 'feature_40', 'feature_41', 'feature_42', 'feature_43', 'feature_44', 'feature_45', 'feature_46', 'feature_47', 'feature_48', 'feature_49', 'feature_50', 'feature_51', 'feature_52', 'feature_53', 'feature_54', 'feature_55', 'feature_56', 'feature_57', 'feature_58', 'feature_59', 'feature_60', 'feature_61', 'feature_62', 'feature_63', 'feature_64', 'feature_65', 'feature_66', 'feature_67', 'feature_68', 'feature_69', 'feature_70', 'fe
# ...

# %%
test_dates = test['date'].value_counts()

print(test_dates)
print(test_dates.min(), test_dates.max())
print(test_dates.index.min(), test_dates.index.max())
# Out:
# 1    9401
# 0    5587
# 2     231
# Name: date, dtype: int64
# 231 9401
# 0 2

# %%
submission = pd.read_csv('../input/jane-street-market-prediction/example_sample_submission.csv')

print('rows', len(submission))
print(list(submission.columns))
# Out:
# rows 15219
# ['ts_id', 'action']

# %%
meta_data = pd.read_csv('../input/jane-street-market-prediction/features.csv')

print(len(meta_data))
print(list(meta_data.columns))
print(meta_data.head())

# 138 rows - same as features
# columns feature, tag_0..tag_28

meta_cols = list(meta_data.columns)
# Out:
# 130
# ['feature', 'tag_0', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6', 'tag_7', 'tag_8', 'tag_9', 'tag_10', 'tag_11', 'tag_12', 'tag_13', 'tag_14', 'tag_15', 'tag_16', 'tag_17', 'tag_18', 'tag_19', 'tag_20', 'tag_21', 'tag_22', 'tag_23', 'tag_24', 'tag_25', 'tag_26', 'tag_27', 'tag_28']
#      feature  tag_0  tag_1  tag_2  tag_3  tag_4  tag_5  tag_6  tag_7  tag_8  \
# 0  feature_0  False  False  False  False  False  False  False  False  False
# 1  feature_1  False  False  False  False  False  False   True   True  False
# 2  feature_2  False  False  False  False  False  False   True   True  False
# 3  feature_3  False  False  False  False  False  False   True  False   True
# 4  feature_4  False  False  False  False  False  False   True  False   True
#
#    tag_9  tag_10  tag_11  tag_12  tag_13  tag_14  tag_15  tag_16  tag_17  \
# 0  False   False   False   False   False   False   False   False   False
# ...

# %%
date_info = train.groupby('date').mean()

print(date_info)
# Out:
#         weight        resp_1        resp_2    resp_3    resp_4      resp  \
# date
# 0     2.004706  1.972580e-05  3.598091e-05  0.000460  0.002755  0.002285
# 1     2.851877  3.875009e-04  3.252212e-04 -0.000121 -0.001623 -0.001195
# 2     0.375123  7.763334e-04  7.763334e-04  0.000771  0.000758  0.000766
# 3     2.637912 -1.895563e-04 -3.165777e-04 -0.000438 -0.001402 -0.001403
# 4     2.464283  5.356287e-04  6.988631e-04  0.000556 -0.000011  0.000334
# 5     3.094972  1.108037e-03  1.603281e-03  0.004873  0.008547  0.005816
# 6     2.416398  2.467702e-04  4.518237e-04  0.001159  0.002422  0.001905
# 7     2.711060 -3.967497e-05 -1.403205e-04 -0.000963 -0.002398 -0.001670
# 8     2.691902  3.368656e-05 -4.849598e-05  0.000659  0.001443  0.000661
# 9     2.539079  4.801770e-04  7.447187e-04  0.001532  0.003966  0.003416
# 10    2.844018 -8.027046e-05  1.875335e-04  0.001050  0.002604  0.002072
# 11    2.438814  1.423604e-05 -1.130051e-04 -0.000320  0.001262  0.001228
# ...

# %%
import random

dates = np.arange(train_dates.index.min(), train_dates.index.max()+1)
random.shuffle(dates)
print(dates)
# Out:
# [231 221 181  90  82 137 143  42  55 453 267 216 283 148 206  20  22 337
#   44 205 288 287  38 484 188 200  28  89 250  87 323 273 163 165 343  56
#  365 394 229  15 391 497 141 387 253 255 464 194 360 235 420 361 340 346
#  227 251 268 149 110 133 242 376 495 256 409 397 116  77 403  10 430 207
#   80  25 455 111 418 339  26  71 310 168 177 336 114 184 276 364 238  54
#  176   9 136  16 147 326 318 196  97  62 226 164 146 467 308 214  73 372
#  371 140 370 424 282 468 225 322  36 197 142 383 368 439 271  31 428 380
#  466 426 179 233 348 378 175 471 230 417  18 232 105  99 401 215 109 405
#  261  95 247 432 475 312 173 490 447 130 461  67 317  29 442 198   7 411
#   96 186 102 249 204 388 446  47 414 494  13 301 462 345 491  41 155 113
#  224 241 275 485  11   6 375  81 159 106 499 402 213 199 483 264 311 290
#  285 103  61 407 435 189 100 460 399 108 272 246 208 443 211  40 161 172
#   98  76 289 132 344 386  33 260 101  66 393 124 309 171 425  72 166 278
# ...
